# %% [markdown]
# # Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Sentiment-Analysis
# !ls|
# Out:
# /content/drive/MyDrive/Colab Notebooks/Sentiment-Analysis
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %% [markdown]
# # Import Dataset

# %%
import pandas as pd

data = pd.read_csv('amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns =['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Data is imbalanced. so, Will do down sampling/upper sampling

# Count the occurrences of each label
label_counts = mydata['label'].value_counts()

# Get the no. of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop >0:
  data_majority = mydata[mydata['label'] == 1]
  data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
  data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced['label'].value_counts())

# Nopw the data is balanced
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list
cleaned_reviews = []
for review in reviews:
    if not isinstance(review, str):
        review = str(review)
    cleaned_reviews.append(clean_text(review))

# %%
# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 9     Love it! I’ve listened to songs I haven’t hear...      1
# 12    I purchased this for my mother who is having k...      1
# 20    Love the Echo and how good the music sounds pl...      1
# 22    Have only had it set up for a few days. Still ...      1
# 23    I love it. It plays my sleep sounds immediatel...      1
# ...                                                 ...    ...
# 3125  This product is easy to use and very entertain...      1
# 3127  works great but speaker is not the good for mu...      1
# 3129  We have six of these throughout our home and t...      1
# 3140                                              Barry      1
# 3148  Only complaint I have is that the sound qualit...      1
#
#                                           clean_reviews
# 9     love it ve listened to songs haven heard since...
# 12    purchased this for my mother who is having kne...
# 20    love the echo and how good the music sounds pl...
# 22    have only had it set up for few days still add...
# 23    love it it plays my sleep sounds immediately w...
# ...                                                 ...
# 3125  this product is easy to use and very entertain...
# 3127  works great but speaker is not the good for mu...
# 3129  we have six of these throughout our home and t...
# 3140                                              barry
# 3148  only complaint have is that the sound quality ...
#
# [514 rows x 3 columns]

# %% [markdown]
# # Data Split

# %%
import pandas as pd

# Assuming your dataframe is 'df'
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# %%
# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# %%
# get the reamining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# # Sentiment w/LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages

import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 98.6 ms, sys: 8.65 ms, total: 107 ms
# Wall time: 6.42 s
# > The meaning of life is a deeply personal and philosophical question that has been pondered by humans for centuries. There is no one definitive answer, as the meaning of life can vary based on individual beliefs, values, and experiences.
# >
# > Some common perspectives on the meaning of life include:
# >
# > **Purpose-Driven:** This view suggests that life has a specific purpose or goal, such as fulfilling a particular role in society, achieving personal fulfillment, or making a positive impact on the world.
# >
# > **Experiential:** This perspective focuses on the value of experiences and moments, emphasizing the importance of living life to the fullest and appreciating the present.
# >
# > **Connection:** This view emphasizes the importance of relationships and connections with others, suggesting that life's meaning is found in our interactions and the love we share.
# >
# > **Growth and Learning:** This perspective sees life as a journey of personal growth and learning, where the pursuit of knowledge, wisdom, and self-improvement brings meaning.
# >
# > **Meaning-Making:** This view suggests that life doesn't have an inherent meaning, but rather that individuals create meaning for themselves through their choices, actions, and beliefs.
# >
# > **Subjective:** This perspective acknowledges that the meaning of life is entirely subjective and varies widely from person to person, depending on their own beliefs, values, and circumstances.
# >
# > Ultimately, the meaning of life is something that each individual must explore and define for themselves. There is no right or wrong answer, and the journey of discovering one's purpose and meaning can be an ongoing and evolving process.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 1208  I love my echo spot that my daughter and son i...      1
# 2307  I like being able to watch pretty much anythin...      1
# 2446                                Great entertainment      1
# 1277  ALEXA IS NOT AS SMART AS SIRI! CANNOT CANCEL S...      0
# 1744  This was my 4th echo device, 1st echo show  it...      0
# 2909  For the price, the product is nice quality and...      0
# 248   I bought this to replace a &#34;Dot&#34; in my...      1
# 2866                             The volume is very low      0
# 2304  I’m very unhappy with this Firestick, every ti...      0
# 994   Too difficult to set up.  It keeps timing out ...      0
# 34                              This device is awesome!      1
# 2019                                                         0
# 2611  This worked well for about 6 months but then s...      0
# 1150                                                         0
# 3148  Only complaint I have is that the sound qualit...      1
# 2867  so far i am liking it although i am probably n...      1
# 2309  The Firestick we were sent doesn’t work. At al...      0
# 12    I purchased this for my mother who is having k...      1
# 806   Sound is terrible if u want good music too get...      0
# 541   Well I’m a big fan of echoes these ones went I...      1
#
#                                           clean_reviews pred_label
# 1208  love my echo spot that my daughter and son in ...
# 2307  like being able to watch pretty much anything ...
# 2446                                great entertainment
# 1277  alexa is not as smart as siri cannot cancel sn...
# 1744  this was my 4th echo device 1st echo show it s...
# 2909  for the price the product is nice quality and ...
# 248   bought this to replace 34 dot 34 in my living ...
# 2866                             the volume is very low
# 2304  very unhappy with this firestick every time we...
# 994   too difficult to set up it keeps timing out be...
# 34                               this device is awesome
# 2019
# 2611  this worked well for about 6 months but then s...
# 1150
# 3148  only complaint have is that the sound quality ...
# 2867  so far am liking it although am probably not u...
# 2309  the firestick we were sent doesn work at all v...
# 12    purchased this for my mother who is having kne...
# 806   sound is terrible if want good music too get bose
# 541   well big fan of echoes these ones went my bath...

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"love my echo spot that my daughter and son in law got me for my birthday alexa wakes me each morning and plays music when ask","pred_label":""},{"clean_reviews":"like being able to watch pretty much anything want at anytime works great","pred_label":""},{"clean_reviews":"great entertainment","pred_label":""},{"clean_reviews":"alexa is not as smart as siri cannot cancel snooze after alarm goes off have to cancel pre set alarm for weekdays","pred_label":""},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"bought this to replace 34 dot 34 in my living room speaker is slightly better it hears me better over the tv unfortunately it doesn understand or respond to my requests as well as the dot frequently have to request 2 or 3 times to get it to do what want the dot usually does exactly what want on the first request don consider it an upgrade","pred_label":""},{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"very unhappy with this firestick every time we change programs or channels within program there is very long delay we have 2 roku that work just fine and are very quick","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"this device is awesome","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this worked well for about 6 months but then stopped connecting to the internet wifi and none of the trouble shooting efforts worked amazon customer service couldn help further and told me warranty was only 3 months which was very disappointing so they weren willing to replace","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"only complaint have is that the sound quality isn great mostly use it for commands though and have another dot hooked up to my stereo system to play music through have couple friends that have dot and don mind the audio quality but if you re bothered by that kind of thing go with the full size echo or make sure you hook the do up to some larger speakers","pred_label":""},{"clean_reviews":"so far am liking it although am probably not using it to the full capasity","pred_label":""},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":"" ...

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"love my echo spot that my daughter and son in law got me for my birthday alexa wakes me each morning and plays music when ask","pred_label":""},{"clean_reviews":"like being able to watch pretty much anything want at anytime works great","pred_label":""},{"clean_reviews":"great entertainment","pred_label":""},{"clean_reviews":"alexa is not as smart as siri cannot cancel snooze after alarm goes off have to cancel pre set alarm for weekdays","pred_label":""},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":""},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":""},{"clean_reviews":"bought this to replace 34 dot 34 in my living room speaker is slightly better it hears me better over the tv unfortunately it doesn understand or respond to my requests as well as the dot frequently have to request 2 or 3 times to get it to do what want the dot usually does exactly what want on the first request don consider it an upgrade","pred_label":""},{"clean_reviews":"the volume is very low","pred_label":""},{"clean_reviews":"very unhappy with this firestick every time we change programs or channels within program there is very long delay we have 2 roku that work just fine and are very quick","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"this device is awesome","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this worked well for about 6 months but then stopped connecting to the internet wifi and none of the trouble shooting efforts worked amazon customer service couldn help further and told me warranty was only 3 months which was very disappointing so they weren willing to replace","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"only complaint have is that the sound quality isn great mostly use it for commands though and have another dot hooked up to my stereo system to play music through have couple friends that have dot and don mind the audio quality but if you re bothered by that kind of thing go with the full size echo or make sure you hook the do up to some larger speakers","pred_label":""},{"clean_reviews":"so far am liking it although am probably not using it to the full capasity","pred_label":""},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":"" ...
# ```

# %%
response = model.generate_content(prompt)
print(response.text)
# Out:
# ```
# [{"clean_reviews":"love my echo spot that my daughter and son in law got me for my birthday alexa wakes me each morning and plays music when ask","pred_label":1},{"clean_reviews":"like being able to watch pretty much anything want at anytime works great","pred_label":1},{"clean_reviews":"great entertainment","pred_label":1},{"clean_reviews":"alexa is not as smart as siri cannot cancel snooze after alarm goes off have to cancel pre set alarm for weekdays","pred_label":0},{"clean_reviews":"this was my 4th echo device 1st echo show it seemed to have huge potential and really wanted to like it but soon found out it is quite limited bit disappointing but not the end of the world used it like use my other screenless echos for little under 2 month when the screen started flickering mostly on the bottom of the screen but not just quick look in some forums made me understand it is pointless asking for replacement as some people had 2 3 devices replaced only to start flickering again shortly after amazon are not providing any serious answers and this has been going on for quite some time apparently long story short moved it to the hallway and been using it as very expensive and bulky voice activated light switch for my hue lights so like the headline suggests meh","pred_label":0},{"clean_reviews":"for the price the product is nice quality and has few nice features so definitely no complaints there the reason why only gave it 3 stars is because the echo dot is not what thought it was going to be so that may just be buyer error first didn know that the product has to be plugged in at all times to work so really don like that it not stand alone device also the speaker is not very loud so if you are buying it as bluetooth speaker don lastly sure the echo dot can do lot but haven quite figured out how to use it fully but it just kind of seems like an unnecessary device to own plus setting it up was awful would definitely save the money and buy the nicer one that is actually alexa","pred_label":0},{"clean_reviews":"bought this to replace 34 dot 34 in my living room speaker is slightly better it hears me better over the tv unfortunately it doesn understand or respond to my requests as well as the dot frequently have to request 2 or 3 times to get it to do what want the dot usually does exactly what want on the first request don consider it an upgrade","pred_label":0},{"clean_reviews":"the volume is very low","pred_label":0},{"clean_reviews":"very unhappy with this firestick every time we change programs or channels within program there is very long delay we have 2 roku that work just fine and are very quick","pred_label":0},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":0},{"clean_reviews":"this device is awesome","pred_label":1},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this worked well for about 6 months but then stopped connecting to the internet wifi and none of the trouble shooting efforts worked amazon customer service couldn help further and told me warranty was only 3 months which was very disappointing so they weren willing to replace","pred_label":0},{"clean_reviews":"","pred_label":""},{"clean_reviews":"only complaint have is that the sound quality isn great mostly use it for commands though and have another dot hooked up to my stereo system to play music through have couple friends that have dot and don mind the audio quality but if you re bothered by that kind of thing go with the full size echo or make sure you hook the do up to some larger speakers","pred_label":1},{"clean_reviews":"so far am liking it although am probably not using it to the full capasity","pred_label":1},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":0},{"clean_revie ...
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews pred_label
# 0   love my echo spot that my daughter and son in ...          1
# 1   like being able to watch pretty much anything ...          1
# 2                                 great entertainment          1
# 3   alexa is not as smart as siri cannot cancel sn...          0
# 4   this was my 4th echo device 1st echo show it s...          0
# 5   for the price the product is nice quality and ...          0
# 6   bought this to replace 34 dot 34 in my living ...          0
# 7                              the volume is very low          0
# 8   very unhappy with this firestick every time we...          0
# 9   too difficult to set up it keeps timing out be...          0
# 10                             this device is awesome          1
# 11
# 12  this worked well for about 6 months but then s...          0
# 13
# 14  only complaint have is that the sound quality ...          1
# 15  so far am liking it although am probably not u...          1
# 16  the firestick we were sent doesn work at all v...          0
# 17  purchased this for my mother who is having kne...          1
# 18  sound is terrible if want good music too get bose          0
# 19  well big fan of echoes these ones went my bath...          1

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 1208  I love my echo spot that my daughter and son i...      1
# 2307  I like being able to watch pretty much anythin...      1
# 2446                                Great entertainment      1
# 1277  ALEXA IS NOT AS SMART AS SIRI! CANNOT CANCEL S...      0
# 1744  This was my 4th echo device, 1st echo show  it...      0
# 2909  For the price, the product is nice quality and...      0
# 248   I bought this to replace a &#34;Dot&#34; in my...      1
# 2866                             The volume is very low      0
# 2304  I’m very unhappy with this Firestick, every ti...      0
# 994   Too difficult to set up.  It keeps timing out ...      0
# 34                              This device is awesome!      1
# 2019                                                         0
# 2611  This worked well for about 6 months but then s...      0
# 1150                                                         0
# 3148  Only complaint I have is that the sound qualit...      1
# 2867  so far i am liking it although i am probably n...      1
# 2309  The Firestick we were sent doesn’t work. At al...      0
# 12    I purchased this for my mother who is having k...      1
# 806   Sound is terrible if u want good music too get...      0
# 541   Well I’m a big fan of echoes these ones went I...      1
#
#                                           clean_reviews pred_label
# 1208  love my echo spot that my daughter and son in ...          1
# 2307  like being able to watch pretty much anything ...          1
# 2446                                great entertainment          1
# 1277  alexa is not as smart as siri cannot cancel sn...          0
# 1744  this was my 4th echo device 1st echo show it s...          0
# 2909  for the price the product is nice quality and ...          0
# 248   bought this to replace 34 dot 34 in my living ...          0
# 2866                             the volume is very low          0
# 2304  very unhappy with this firestick every time we...          0
# 994   too difficult to set up it keeps timing out be...          0
# 34                               this device is awesome          1
# 2019
# 2611  this worked well for about 6 months but then s...          0
# 1150
# 3148  only complaint have is that the sound quality ...          1
# 2867  so far am liking it although am probably not u...          1
# 2309  the firestick we were sent doesn work at all v...          0
# 12    purchased this for my mother who is having kne...          1
# 806   sound is terrible if want good music too get bose          0
# 541   well big fan of echoes these ones went my bath...          1

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import accuracy_score

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

accuracy_score(y_true, y_pred)

# %%
# Accuracy = TP+TN/ Total = 9+7/20 ~ 80%
